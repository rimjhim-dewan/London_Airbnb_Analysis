# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('nyearsupdate.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 name host_name   latitude  \
# 0            Lovely private bedroom in Muswell Hill.   Forough  51.597280
# 1                       Studio Flat  Franklin London   Hussein  51.636518
# 2   PropertyPlug - 2Bed Flat in Edgware SmartTV WiFi      Paul  51.608180
# 3                   Wimbledon Double Bedroom Ensuite     Nikki  51.422310
# 4  Stunning Apartment 2 minutes walk to Tube Station    Joseph  51.602282
#
#    longitude  host_since           host_location host_acceptance_rate  \
# 0  -0.139330           8  London, United Kingdom                  NaN
# 1  -0.177475           0  London, United Kingdom                 100%
# 2  -0.277400           3                     NaN                  91%
# ...

# %%
df['host_acceptance_rate'].value_counts()
# Out:
# 100%    16340
# 99%      4319
# 98%      2605
# 97%      1859
# 0%       1716
#         ...
# 8%          5
# 16%         4
# 12%         4
# 1%          3
# 4%          1
# Name: host_acceptance_rate, Length: 100, dtype: int64

# %%
for i in range(len(df)):  
    if(type(df['host_acceptance_rate'][i])==str):
        df['host_acceptance_rate'][i]=int(df['host_acceptance_rate'][i][:-1])
    else:
        df['host_acceptance_rate'][i]=78
# Out:
# C:\Users\chinm\AppData\Local\Temp\ipykernel_1320\2870775202.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_acceptance_rate'][i]=78
# C:\Users\chinm\AppData\Local\Temp\ipykernel_1320\2870775202.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_acceptance_rate'][i]=int(df['host_acceptance_rate'][i][:-1])

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 name host_name   latitude  \
# 0            Lovely private bedroom in Muswell Hill.   Forough  51.597280
# 1                       Studio Flat  Franklin London   Hussein  51.636518
# 2   PropertyPlug - 2Bed Flat in Edgware SmartTV WiFi      Paul  51.608180
# 3                   Wimbledon Double Bedroom Ensuite     Nikki  51.422310
# 4  Stunning Apartment 2 minutes walk to Tube Station    Joseph  51.602282
#
#    longitude  host_since           host_location host_acceptance_rate  \
# 0  -0.139330           8  London, United Kingdom                   78
# 1  -0.177475           0  London, United Kingdom                  100
# 2  -0.277400           3                     NaN                   91
# ...

# %%
for i in range(len(df)):  
    if(df['review_scores_rating'][i]>=0.5 and df['review_scores_rating'][i]<=6):
       print("a")
    else:
        df['review_scores_rating'][i]=3
# Out:
# C:\Users\chinm\AppData\Local\Temp\ipykernel_1320\34068135.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review_scores_rating'][i]=3
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# ...

# %%
x=df.isna()
x['review_scores_rating'].value_counts()
# Out:
# False    75236
# Name: review_scores_rating, dtype: int64

# %%
df['review_rating']=df['number_of_reviews']*df['review_scores_rating']

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 name host_name   latitude  \
# 0            Lovely private bedroom in Muswell Hill.   Forough  51.597280
# 1                       Studio Flat  Franklin London   Hussein  51.636518
# 2   PropertyPlug - 2Bed Flat in Edgware SmartTV WiFi      Paul  51.608180
# 3                   Wimbledon Double Bedroom Ensuite     Nikki  51.422310
# 4  Stunning Apartment 2 minutes walk to Tube Station    Joseph  51.602282
#
#    longitude  host_since           host_location host_acceptance_rate  \
# 0  -0.139330           8  London, United Kingdom                   78
# 1  -0.177475           0  London, United Kingdom                  100
# 2  -0.277400           3                     NaN                   91
# ...

# %%
x=df.columns

# %%
df.drop(columns=x[0:2],inplace=True)

# %%
df.head()
# Out:
#                                                 name host_name   latitude  \
# 0            Lovely private bedroom in Muswell Hill.   Forough  51.597280
# 1                       Studio Flat  Franklin London   Hussein  51.636518
# 2   PropertyPlug - 2Bed Flat in Edgware SmartTV WiFi      Paul  51.608180
# 3                   Wimbledon Double Bedroom Ensuite     Nikki  51.422310
# 4  Stunning Apartment 2 minutes walk to Tube Station    Joseph  51.602282
#
#    longitude  host_since           host_location host_acceptance_rate  \
# 0  -0.139330           8  London, United Kingdom                   78
# 1  -0.177475           0  London, United Kingdom                  100
# 2  -0.277400           3                     NaN                   91
# 3  -0.188410          13  London, United Kingdom                  100
# 4  -0.193606           9                     NaN                   46
#
#                  property_type        room_type  price  minimum_nights  \
# ...

# %%
df['host_location'].value_counts()
# Out:
# London, United Kingdom              42757
# England, United Kingdom             10018
# United Kingdom                        664
# Paris, France                         227
# New York, NY                          128
#                                     ...
# Welham, United Kingdom                  1
# Mulheim, Germany, Germany               1
# Englefield Green, United Kingdom        1
# Uppsala, Sweden                         1
# Grand Forks, ND                         1
# Name: host_location, Length: 1558, dtype: int64
